# %%
# !pip install -q condacolab

# %%
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:12
# 🔁 Restarting kernel...

# %%
# !conda --version
# Out:
# conda 24.11.2

# %%
# !conda create -n pmrf python=3.10
# !conda activate pmrf
# !conda install pytorch==2.3.1 torchvision==0.18.1 torchaudio==2.3.1 pytorch-cuda=11.8 -c pytorch -c nvidia
# !conda install lightning==2.3.3 -c conda-forge
# !pip install opencv-python==4.10.0.84 timm==1.0.8 wandb==0.17.5 lovely-tensors==0.1.16 torch-fidelity==0.3.0 einops==0.8.0 dctorch==0.1.2 torch-ema==0.3
# !pip install natten==0.17.1+torch230cu118 -f https://shi-labs.com/natten/wheels
# !pip install nvidia-cuda-nvcc-cu11
# !pip install basicsr==1.4.2
# !pip install git+https://github.com/toshas/torch-fidelity.git
# !pip install lpips==0.1.4
# !pip install piq==0.8.0
# !pip install huggingface_hub==0.24.5
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.7.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/pmrf
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.8.3   |       hbd8a1cb_0         151 KB  conda-forge
#     ld_impl_linux-64-2.44      |       h1423503_1         660 KB  conda-forge
#     libexpat-2.7.1             |       hecca717_0          73 KB  conda-forge
#     libffi-3.4.6               |       h2dba641_1          56 KB  conda-forge
#     libgcc-15.1.0              |       h767d61c_4         805 KB  conda-forge
# ...

# %%
# !git clone https://github.com/ohayonguy/PMRF.git
# Out:
# Cloning into 'PMRF'...
# remote: Enumerating objects: 186, done.
# remote: Counting objects: 100% (186/186), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 186 (delta 77), reused 153 (delta 56), pack-reused 0 (from 0)
# Receiving objects: 100% (186/186), 23.21 MiB | 15.88 MiB/s, done.
# Resolving deltas: 100% (77/77), done.

# %%
# %cd PMRF
# Out:
# /content/PMRF

# %%
# !python inference.py \
--ckpt_path ohayonguy/PMRF_blind_face_image_restoration \
--ckpt_path_is_huggingface \
--lq_data_path /content/drive/MyDrive/test \
--output_dir /content/drive/MyDrive/test/output \
--batch_size 64 \
--num_flow_steps 25
# Out:
# config.json: 100% 368/368 [00:00<00:00, 2.58MB/s]
# Downloading: "https://github.com/toshas/torch-fidelity/releases/download/v0.2.0/weights-inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/weights-inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:00<00:00, 229MB/s]
# /usr/local/lib/python3.11/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: Metric `InceptionScore` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# model.safetensors: 100% 923M/923M [00:07<00:00, 120MB/s]
# Compiled model
#   0% 0/1 [00:00<?, ?it/s]
#   0% 0/3 [00:00<?, ?it/s]
#  33% 1/3 [00:00<00:00,  4.98it/s]
#  67% 2/3 [00:00<00:00,  5.32it/s]
# 100% 3/3 [00:00<00:00,  5.52it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  33% 1/3 [00:00<00:00,  2.84it/s]
#  67% 2/3 [00:00<00:00,  4.27it/s]
# 100% 3/3 [00:00<00:00,  4.67it/s]
# 100% 1/1 [00:49<00:00, 49.14s/it]
